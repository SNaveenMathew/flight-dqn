# %%
import pandas as pd
import matplotlib.pyplot as plt

ac_data = pd.read_csv("../../touchdown.csv")

# %%
plt.hist(ac_data["azimuth"], bins=20)
plt.title("Distribution of Azimuth during Touchdown")
plt.show()
